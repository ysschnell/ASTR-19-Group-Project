# %%
import numpy as np
from scipy import optimize
import matplotlib.pyplot as plt

# %%
tide_data = np.genfromtxt('ASTR19_F25_group_project_data.txt', 
                  dtype = None, encoding = 'utf-8')

# x = np.linspace(0, 72, 200)
# a, b = 2.2, 1.0
# T1 = 12
# T2 = 24

# y = a * np.sin(2*np.pi * x /T1) + b * np.sin(2*np.pi * x /T2)
# print(y)
# print(x)

# init = x[0][0]
# print(init)

times = []
for time in tide_data:
    times.append(time[1])

print(times)
    # for entry in tuple:
    #     print(entry[1])


time_of_day_hours = []
for time_string in times:
    h_string, m_string = time_string.split(':')
    h = int(h_string)
    m = int(m_string)
    t_hours = h + m/60
    time_of_day_hours.append(t_hours)
print(time_of_day_hours)


days = []
for i in tide_data:
    days.append(i[0])

# print(days)

day_0 = days[0]

total_hours = []
for day, t_hours in zip(days, time_of_day_hours):
    hrs = 24 * (day - day_0) + t_hours
    total_hours.append(hrs)

print(total_hours)
# Out:
# ['8:07', '15:37', '8:55', '16:25', '9:45', '17:14', '10:35', '18:00', '11:28', '18:46', '12:22', '19:31', '13:24', '20:16', '3:22', '21:01', '4:07', '21:46', '4:50', '11:58', '5:31', '12:56', '6:08', '13:45', '6:47', '14:25', '7:22', '15:00', '7:59', '15:34', '8:34', '16:08', '9:10', '16:41', '9:45', '17:12', '10:21', '17:45', '10:57', '18:15', '11:38', '18:48', '12:25', '19:20', '2:22', '19:52', '2:58', '20:30', '3:37', '10:44', '4:23', '11:55', '5:15', '12:57', '6:09', '13:50', '7:05', '14:39', '7:58', '15:27', '8:50', '16:10', '9:40', '16:52', '10:30', '17:34', '11:19', '18:12', '12:10', '18:49', '1:32', '19:24', '2:13', '20:00', '2:54', '9:54', '3:39', '11:15', '4:29', '12:22', '5:21', '13:14']
# [8.116666666666667, 15.616666666666667, 8.916666666666666, 16.416666666666668, 9.75, 17.233333333333334, 10.583333333333334, 18.0, 11.466666666666667, 18.766666666666666, 12.366666666666667, 19.516666666666666, 13.4, 20.266666666666666, 3.3666666666666667, 21.016666666666666, 4.116666666666666, 21.766666666666666, 4.833333333333333, 11.966666666666667, 5.516666666666667, 12.933333333333334, 6.133333333333334, 13.75, 6.783333333333333, 14.416666666666666, 7.366666666666666, 15.0, 7.983333333333333, 15.566666666666666, 8.566666666666666, 16.133333333333333, 9.166666666666666, 16.683333333333334, 9.75, 17.2, 10.35, 17.75, 10.95, 18.25, 11.633333333333333, 18.8, 12.416666666666666, 19.333333333333332, 2.3666666666666667, 19.866666666666667, 2.966666666666667, 20.5, 3.6166666666666667, 10.733333333333333, 4.383333333333334, 11.916666666666666, 5.25, 12.95, 6.15, 13.833333333333334, 7.083333333333333, 14.65, 7.966666666666667, 15.45, 8.833333333333334, 16.166666666666668, 9.666666666666666, 16.866666666666667, 10.5, 17.566666666666666, 11.316666666666666, 18.2, 12.166666666666666, 18.816666666666666, 1.5333333333333332, 19.4, 2.216666666666667, 20.0, 2.9, 9.9, 3.65, 11.25, 4.483333333333333, 12.366666666666667, 5.35, 13.233333333333333]
# [8.116666666666667, 15.616666666666667, 32.916666666666664, 40.41666666666667, 57.75, 65.23333333333333, 82.58333333333333, 90.0, 107.46666666666667, 114.76666666666667, 132.36666666666667, 139.51666666666665, 157.4, 164.26666666666665, 171.36666666666667, 189.01666666666665, 196.11666666666667, 213.76666666666665, 220.83333333333334, 227.96666666666667, 245.51666666666668, 252.93333333333334, 270.1333333333333, 277.75, 294.78333333333336, 302.4166666666667, 319.3666666666667, 327.0, 343.98333333333335, 351.56666666666666, 368.56666666666666, 376.1333333333333, 393.1666666666667, 400.68333333333334, 417.75, 425.2, 442.35, 449.75, 466.95, 474.25, 491.6333333333333, 498.8, 516.4166666666666, 523.3333333333334, 530.3666666666667, 547.8666666666667, 554.9666666666667, 572.5, 579.6166666666667, 586.7333333333333, 604.3833333333333, 611.9166666666666, 629.25, 636.95, 654.15, 661.8333333333334, 679.0833333333334, 686.65, 703.9666666666667, 711.45, 728.8333333333334, 736.1666666666666, 753.6666666666666, 760.8666666666667, 778.5, 785.5666666666667, 803.3166666666667, 810.2, 828.1666666666666, 834.8166666666667, 841.5333333333333, 859.4, 866.2166666666667, 884.0, 890.9, 897.9, 915.65, 923.25, 940.4833333333333, 948.3666666666667, 965.35, 973.2333333333333]

# %%
x = np.array(total_hours)


heights = []
for row in tide_data:
    heights.append(row[2])

y = np.array(heights)
print(y)
# Out:
# [ 6.57 -0.39  5.38 -1.74  5.26 -1.36  4.13 -1.15  3.48 -1.61  2.62  0.05
#   1.83  1.01  3.57  0.73  4.54  2.17  3.76  2.88  3.9   1.92  4.73  1.74
#   5.66  0.79  5.33 -0.04  5.23 -1.12  6.67 -0.61  4.74 -0.93  4.69 -1.29
#   4.2   0.22  3.68  0.26  2.47  0.36  2.59  0.99  4.1   1.87  3.17  1.6
#   3.71  3.1   4.04  2.49  4.07  2.18  5.93  0.7   6.89  0.21  6.72  0.22
#   6.77 -1.68  5.77 -1.32  4.35 -0.73  4.23 -0.38  2.24 -0.61  3.45 -0.46
#   4.13  1.21  3.34  2.58  3.32  3.26  5.21  2.39  4.83  2.41]

# %%
def tide_model(x, a, b, phi_1, phi_2, c):
    return a * np.sin(2*np.pi * x/12 + phi_1) + b * np.sin(2*np.pi * x/24 + phi_2) + c

# %%
params, params_cov = optimize.curve_fit(tide_model, x, y, sigma = 0.25)
print(params)

a_fit = params[0]
b_fit = params[1]
phi_1_fit = params[2]
phi_2_fit = params[3]
c_fit = params[4]

y_fit = a_fit * np.sin(2*np.pi * x/12 + phi_1_fit) + b_fit * np.sin(2*np.pi * x/24 + phi_2_fit) + c_fit
# y_fit = a_fit * np.sin(2*np.pi * x/T1) + b_fit * np.sin(2*np.pi * x/T2)
residuals = y - y_fit 
# print(residuals)
# Out:
# [9.24282852e-01 2.83056094e+00 9.08784623e+00 3.40032409e-03
#  2.58037166e+00]

# %%
plt.plot(x, y, 'o', color = 'red', label = 'data')
plt.plot(x, y_fit, '--', color = 'blue', label = 'fit')
plt.xlabel('Time since first measurement (hours)')
plt.ylabel('Tide height (ft)')
plt.title('Tide Data and Best-Fit Model')
plt.legend()
plt.savefig('tide_data_fit.pdf', bbox_inches='tight', dpi=300)

# %%
plt.figure(figsize=(7,7))
plt.plot(x, residuals, 'o', markersize = 4)
plt.xlabel('Time since first measurement (hours)')
plt.ylabel('Residual height (ft)')
plt.title('Residuals vs Time')
plt.savefig('residuals.pdf', bbox_inches='tight', dpi=300)
plt.show()

# %%
sigma = 0.25

res_std = np.std(residuals, ddof=1)
print("Std dev of residuals:", res_std)
print("Assumed measurement error (ft):", sigma)
# Out:
# Std dev of residuals: 0.6775969609923415
# Assumed measurement error (ft): 0.25

# %%
plt.figure(figsize = (7,7))

plt.xlabel('Residual height [ft]')   # (data - model)
plt.ylabel('Count')
plt.title('Histogram of Tide Residuals')

plt.hist(residuals, bins = 20)

plt.savefig('tide_histogram', bbox_inches = 'tight', dpi = 300)
plt.show()

# %%
tsunami_residual = 2.0

N_sigma = tsunami_residual / res_std

print('Tsunami deviation:', N_sigma)
# Out:
# Tsunami deviation: 2.951607098519152

# %%
residuals_list = list(residuals)
residuals_list.append(2.0)
residuals_with_tsunami = np.array(residuals_list)

# residuals_with_tsunami = np.append(residuals, tsunami_residual)

plt.figure()

plt.hist(residuals_with_tsunami, bins=20)

plt.xlabel("Residual height [ft]")
plt.ylabel("Count")
plt.title("Histogram of Residuals with Tsunami Outlier")

plt.axvline(tsunami_residual, color='red', linestyle='-', label='Tsunami (+2 ft)')
plt.legend()

plt.savefig("residual_hist_with_tsunami.pdf", bbox_inches='tight', dpi=300)
plt.show()
